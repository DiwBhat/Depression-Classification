# %% [markdown]
# ### Imports and Configurations

# %%
# Imports
import pandas as pd
import numpy as np
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_val_score

from sklearn.metrics import (
    accuracy_score, 
    confusion_matrix, 
    classification_report, 
    roc_auc_score, 
    roc_curve,
    precision_recall_curve,
    auc
)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.stats import uniform, randint
import joblib

# Configurations
# %matplotlib inline
sns.set(style="whitegrid")
warnings.filterwarnings('ignore') 

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ### Loading the Data

# %%
input_filename = 'cleaned_student_data.csv' 

df_model = pd.read_csv(input_filename)
print(f"\nLoaded data from '{input_filename}'. Shape: {df_model.shape}")

# Quick verification:
print("\nVerifying column types:\n")
print(df_model.info())

# Checking if 'Depression' column exists
if 'Depression' not in df_model.columns:
    raise ValueError("Target column 'Depression' not found in the loaded data.")
# Out:
# Loaded data from 'cleaned_student_data.csv'. Shape: (27851, 91)
#
# Verifying column types:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27851 entries, 0 to 27850
# Data columns (total 91 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Age                                        27851 non-null  float64
#  1   Academic Pressure                          27851 non-null  float64
#  2   CGPA                                       27851 non-null  float64
#  3   Study Satisfaction                         27851 non-null  float64
#  4   Suicidal_Thoughts                          27851 non-null  int64
#  5   Work/Study Hours                           27851 non-null  float64
#  6   Financial Stress                           27851 non-null  float64
#  7   Family History of Mental Illness           27851 non-null  int64
#  8   Depression                                 27851 non-null  int64
#  9   Sleep_Ordinal                              27851 non-null  int64
#  10  Total_Stress                               27851 non-null  float64
#  11  Gender_Male                                27851 non-null  bool
#  12  City_Ahmedabad                             27851 non-null  bool
#  13  City_Bangalore                             27851 non-null  bool
#  14  City_Bhopal                                27851 non-null  bool
#  15  City_Chennai                               27851 non-null  bool
#  16  City_Delhi                                 27851 non-null  bool
#  17  City_Faridabad                             27851 non-null  bool
#  18  City_Ghaziabad                             27851 non-null  bool
#  19  City_Hyderabad                             27851 non-null  bool
#  20  City_Indore                                27851 non-null  bool
#  21  City_Jaipur                                27851 non-null  bool
#  22  City_Kalyan                                27851 non-null  bool
#  23  City_Kanpur                                27851 non-null  bool
#  24  City_Kolkata                               27851 non-null  bool
#  25  City_Lucknow                               27851 non-null  bool
#  26  City_Ludhiana                              27851 non-null  bool
#  27  City_Meerut                                27851 non-null  bool
#  28  City_Mumbai                                27851 non-null  bool
#  29  City_Nagpur                                27851 non-null  bool
#  30  City_Nashik                                27851 non-null  bool
#  31  City_Patna                                 27851 non-null  bool
#  32  City_Pune                                  27851 non-null  bool
#  33  City_Rajkot                                27851 non-null  bool
#  34  City_Srinagar                              27851 non-null  bool
#  35  City_Surat                                 27851 non-null  bool
#  36  City_Thane                                 27851 non-null  bool
#  37  City_Vadodara                              27851 non-null  bool
#  38  City_Varanasi                              27851 non-null  bool
#  39  City_Vasai-Virar                           27851 non-null  bool
#  40  City_Visakhapatnam                         27851 non-null  bool
#  41  Dietary Habits_Moderate                    27851 non-null  bool
#  42  Dietary Habits_Others                      27851 non-null  bool
#  43  Dietary Habits_Unhealthy                   27851 non-null  bool
#  44  Degree_B.Com                               27851 non-null  bool
#  45  Degree_B.Ed                                27851 non-null  bool
#  46  Degree_B.Pharm                             27851 non-null  bool
#  47  Degree_B.Tech                              27851 non-null  bool
#  48  Degree_BA                                  27851 non-null  bool
#  49  Degree_BBA                                 27851 non-null  bool
#  50  Degree_BCA                                 27851 non-null  bool
#  51  Degree_BE                                  27851 non-null  bool
#  52  Degree_BHM                                 27851 non-null  bool
#  53  Degree_BSc                                 27851 non-null  bool
#  54  Degree_Class 12                            27851 non-null  bool
#  55  Degree_LLB                                 27851 non-null  bool
#  56  Degree_LLM                                 27851 non-null  bool
#  57  Degree_M.Com                               27851 non-null  bool
#  58  Degree_M.Ed                                27851 non-null  bool
#  59  Degree_M.Pharm                             27851 non-null  bool
#  60  Degree_M.Tech                              27851 non-null  bool
#  61  Degree_MA                                  27851 non-null  bool
#  62  Degree_MBA                                 27851 non-null  bool
#  63  Degree_MBBS                                27851 non-null  bool
#  64  Degree_MCA                                 27851 non-null  bool
#  65  Degree_MD                                  27851 non-null  bool
#  66  Degree_ME                                  27851 non-null  bool
#  67  Degree_MHM                                 27851 non-null  bool
#  68  Degree_MSc                                 27851 non-null  bool
#  69  Degree_Others                              27851 non-null  bool
#  70  Degree_PhD                                 27851 non-null  bool
#  71  Age_Group_25-30                            27851 non-null  bool
#  72  Age_Group_31-39                            27851 non-null  bool
#  73  Region_Eastern                             27851 non-null  bool
#  74  Region_Northern                            27851 non-null  bool
#  75  Region_Southern                            27851 non-null  bool
#  76  Region_Western                             27851 non-null  bool
#  77  Degree_Level_Class 12                      27851 non-null  bool
#  78  Degree_Level_Masters                       27851 non-null  bool
#  79  Degree_Level_Other/Unknown                 27851 non-null  bool
#  80  Degree_Level_PhD                           27851 non-null  bool
#  81  Degree_Field_Arts/Humanities/Edu           27851 non-null  bool
#  82  Degree_Field_Business/Mgmt                 27851 non-null  bool
#  83  Degree_Field_Engineering/Tech              27851 non-null  bool
#  84  Degree_Field_General/Other                 27851 non-null  bool
#  85  Degree_Field_Law                           27851 non-null  bool
#  86  Degree_Field_Medical/Pharma                27851 non-null  bool
#  87  Degree_Field_PhD                           27851 non-null  bool
#  88  Degree_Field_Science                       27851 non-null  bool
#  89  Degree_Type_Non-Science/Arts/Business/Law  27851 non-null  bool
#  90  Degree_Type_Science/Tech                   27851 non-null  bool
# dtypes: bool(80), float64(7), int64(4)
# memory usage: 4.5 MB
# None

# %% [markdown]
# ### Separating Features (X) and Target (y)

# %%
target_column = 'Depression'
y = df_model[target_column]
X = df_model.drop(columns=[target_column])

print(f"\nFeatures (X) shape: {X.shape}")
print(f"Target (y) shape: {y.shape}")

print("\nFeature columns used for training:\n")
print(list(X.columns))
# Out:
# Features (X) shape: (27851, 90)
# Target (y) shape: (27851,)
#
# Feature columns used for training:
#
# ['Age', 'Academic Pressure', 'CGPA', 'Study Satisfaction', 'Suicidal_Thoughts', 'Work/Study Hours', 'Financial Stress', 'Family History of Mental Illness', 'Sleep_Ordinal', 'Total_Stress', 'Gender_Male', 'City_Ahmedabad', 'City_Bangalore', 'City_Bhopal', 'City_Chennai', 'City_Delhi', 'City_Faridabad', 'City_Ghaziabad', 'City_Hyderabad', 'City_Indore', 'City_Jaipur', 'City_Kalyan', 'City_Kanpur', 'City_Kolkata', 'City_Lucknow', 'City_Ludhiana', 'City_Meerut', 'City_Mumbai', 'City_Nagpur', 'City_Nashik', 'City_Patna', 'City_Pune', 'City_Rajkot', 'City_Srinagar', 'City_Surat', 'City_Thane', 'City_Vadodara', 'City_Varanasi', 'City_Vasai-Virar', 'City_Visakhapatnam', 'Dietary Habits_Moderate', 'Dietary Habits_Others', 'Dietary Habits_Unhealthy', 'Degree_B.Com', 'Degree_B.Ed', 'Degree_B.Pharm', 'Degree_B.Tech', 'Degree_BA', 'Degree_BBA', 'Degree_BCA', 'Degree_BE', 'Degree_BHM', 'Degree_BSc', 'Degree_Class 12', 'Degree_LLB', 'Degree_LLM', 'Degree_M.Com', 'Degree_M.Ed', 'Degree_M.Pharm', 'Degree_M.Tech', 'Degree_MA', 'Degree_MBA', 'Degree_MBBS', 'Degree_MCA', 'Degree_MD', 'Degree_ME', 'Degree_MHM', 'Degree_MSc', 'Degree_Others', 'Degree_PhD', 'Age_Group_25-30', 'Age_Group_31-39', 'Region_Eastern', 'Region_Northern', 'Region_Southern', 'Region_Western', 'Degree_Level_Class 12', 'Degree_Level_Masters', 'Degree_Level_Other/Unknown', 'Degree_Level_PhD', 'Degree_Field_Arts/Humanities/Edu', 'Degree_Field_Business/Mgmt', 'Degree_Field_Engineering/Tech', 'Degree_Field_General/Other', 'Degree_Field_Law', 'Degree_Field_Medical/Pharma', 'Degree_Field_PhD', 'Degree_Field_Science', 'Degree_Type_Non-Science/Arts/Business/Law', 'Degree_Type_Science/Tech']

# %% [markdown]
# ### Checking Class Balance

# %%
print("\nTarget Variable Distribution\n")
class_counts = y.value_counts(normalize=True) * 100
print(class_counts)

# Calculating scale_pos_weight for potential use if classes are imbalanced

count_neg = y.value_counts()[0]
count_pos = y.value_counts()[1]

# Handle potential division by zero 
scale_pos_weight_value = 1 
if count_pos > 0:
    scale_pos_weight_value = count_neg / count_pos
print(f"\nCalculated scale_pos_weight: {scale_pos_weight_value:.2f}")
# Out:
# Target Variable Distribution
#
# Depression
# 1    58.575994
# 0    41.424006
# Name: proportion, dtype: float64
#
# Calculated scale_pos_weight: 0.71

# %% [markdown]
# ### Splitting Data into Training and Testing Sets

# %%
# Using stratify=y to maintain class proportions in train/test splits

test_set_size = 0.2
random_seed = 42   

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=test_set_size, 
    random_state=random_seed, 
    stratify=y  
)

print(f"Training set shape: X_train={X_train.shape}, y_train={y_train.shape}")
print(f"Testing set shape: X_test={X_test.shape}, y_test={y_test.shape}")
print(f"\nTraining set target distribution:\n{y_train.value_counts(normalize=True) * 100}")
print(f"\nTesting set target distribution:\n{y_test.value_counts(normalize=True) * 100}")
# Out:
# Training set shape: X_train=(22280, 90), y_train=(22280,)
# Testing set shape: X_test=(5571, 90), y_test=(5571,)
#
# Training set target distribution:
# Depression
# 1    58.577199
# 0    41.422801
# Name: proportion, dtype: float64
#
# Testing set target distribution:
# Depression
# 1    58.571172
# 0    41.428828
# Name: proportion, dtype: float64

# %% [markdown]
# ### Initialize and Train XGBoost Model

# %%
def objective(trial):
    """Optuna objective function to minimize/maximize."""
    
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',  
        'booster': 'gbtree',
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=50), # Explore # of trees
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True), # Explore learning rate on log scale
        'max_depth': trial.suggest_int('max_depth', 3, 10), # Explore tree depth
        'subsample': trial.suggest_float('subsample', 0.6, 1.0, step=0.05), # Explore subsample ratio
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0, step=0.05), # Explore feature sampling
        'gamma': trial.suggest_float('gamma', 0.0, 0.5, step=0.05), # Explore gamma
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10), # Explore min child weight
        'lambda': trial.suggest_float('lambda', 1e-3, 1.0, log=True), # L2 regularization
        'alpha': trial.suggest_float('alpha', 1e-3, 1.0, log=True),   # L1 regularization
        'random_state': 42, 
    }
    
    model = xgb.XGBClassifier(**params)
    
    n_splits_cv = 5
    cv_strategy = StratifiedKFold(n_splits=n_splits_cv, shuffle=True, random_state=42)
    
    # Performing cross-validation and get the average score
    # Using roc_auc as the scoring metric for optimization
    
    score = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv_strategy, n_jobs=-1)
    
    return score.mean()

# %%
# Create and Run the Optuna Study

n_trials = 50  # Number of optimization trials to run.
study_name = 'xgboost-hyperopt' 

print(f"\nStarting Optuna Optimization ({n_trials} trials, optimizing ROC AUC)\n")

study = optuna.create_study(direction="maximize", study_name=study_name)
study.optimize(objective, n_trials=n_trials, timeout=600)
print("\nOptuna Optimization Complete\n")


# Get Best Results from Optuna 
print(f"\nNumber of finished trials: {len(study.trials)}")
print(f"Best trial number: {study.best_trial.number}")
print(f"Best ROC AUC (CV on Train Set): {study.best_value:.4f}")

print("\nBest Parameters found:\n")
best_params = study.best_params
print(best_params)
# Out:
# [I 2025-05-05 11:19:28,150] A new study created in memory with name: xgboost-hyperopt
# Starting Optuna Optimization (50 trials, optimizing ROC AUC)
# [I 2025-05-05 11:19:30,041] Trial 0 finished with value: 0.9049112476333218 and parameters: {'n_estimators': 550, 'learning_rate': 0.29298530590975047, 'max_depth': 4, 'subsample': 0.85, 'colsample_bytree': 0.6, 'gamma': 0.15000000000000002, 'min_child_weight': 6, 'lambda': 0.005424421984859874, 'alpha': 0.019187107908368563}. Best is trial 0 with value: 0.9049112476333218.
# [I 2025-05-05 11:19:31,862] Trial 1 finished with value: 0.9165659039464916 and parameters: {'n_estimators': 550, 'learning_rate': 0.04988477300925061, 'max_depth': 6, 'subsample': 0.9, 'colsample_bytree': 0.65, 'gamma': 0.25, 'min_child_weight': 5, 'lambda': 0.018432193599147013, 'alpha': 0.04433933025750088}. Best is trial 1 with value: 0.9165659039464916.
# [I 2025-05-05 11:19:33,060] Trial 2 finished with value: 0.920525456632852 and parameters: {'n_estimators': 150, 'learning_rate': 0.049664305356861095, 'max_depth': 4, 'subsample': 1.0, 'colsample_bytree': 0.85, 'gamma': 0.4, 'min_child_weight': 8, 'lambda': 0.04907532483684831, 'alpha': 0.06204383308748043}. Best is trial 2 with value: 0.920525456632852.
# [I 2025-05-05 11:19:35,250] Trial 3 finished with value: 0.8983823711842746 and parameters: {'n_estimators': 700, 'learning_rate': 0.29844313813742046, 'max_depth': 7, 'subsample': 0.85, 'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 2, 'lambda': 0.003999092975514917, 'alpha': 0.24300288154438088}. Best is trial 2 with value: 0.920525456632852.
# [I 2025-05-05 11:19:36,445] Trial 4 finished with value: 0.904198067919765 and parameters: {'n_estimators': 700, 'learning_rate': 0.2417848388242088, 'max_depth': 4, 'subsample': 0.85, 'colsample_bytree': 0.8, 'gamma': 0.1, 'min_child_weight': 1, 'lambda': 0.0021208999678927675, 'alpha': 0.9162941218873346}. Best is trial 2 with value: 0.920525456632852.
# [I 2025-05-05 11:19
. Best is trial 34 with value: 0.9215228846131126.
# [I 2025-05-05 11:20:07,753] Trial 38 finished with value: 0.9209586223607381 and parameters: {'n_estimators': 250, 'learning_rate': 0.04077706022435772, 'max_depth': 4, 'subsample': 0.9, 'colsample_bytree': 0.85, 'gamma': 0.35000000000000003, 'min_child_weight': 8, 'lambda': 0.014350913115414074, 'alpha': 0.8570095834651373}. Best is trial 34 with value: 0.9215228846131126.
# [I 2025-05-05 11:20:08,735] Trial 39 finished with value: 0.9185142466851637 and parameters: {'n_estimators': 350, 'learning_rate': 0.04472085735026013, 'max_depth': 6, 'subsample': 0.85, 'colsample_bytree': 0.8, 'gamma': 0.4, 'min_child_weight': 9, 'lambda': 0.041415022459770134, 'alpha': 0.06377238515387873}. Best is trial 34 with value: 0.9215228846131126.
# [I 2025-05-05 11:20:10,015] Trial 40 finished with value: 0.9200210167419612 and parameters: {'n_estimators': 800, 'learning_rate': 0.050810160623744376, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.85, 'gamma': 0.15000000000000002, 'min_child_weight': 10, 'lambda': 0.014417355682421869, 'alpha': 0.05972338310145414}. Best is trial 34 with value: 0.9215228846131126.
# [I 2025-05-05 11:20:10,519] Trial 41 finished with value: 0.9214321480687062 and parameters: {'n_estimators': 200, 'learning_rate': 0.06238512820132876, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.75, 'gamma': 0.35000000000000003, 'min_child_weight': 8, 'lambda': 0.02341366153191654, 'alpha': 0.2987826921038137}. Best is trial 34 with value: 0.9215228846131126.
# [I 2025-05-05 11:20:11,023] Trial 42 finished with value: 0.9215268310128101 and parameters: {'n_estimators': 200, 'learning_rate': 0.060117183434070784, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.75, 'gamma': 0.30000000000000004, 'min_child_weight': 9, 'lambda': 0.0029278622871275056, 'alpha': 0.20033053974980772}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:11,467] Trial 43 finished with value: 0.9210012133956254 and parameters: {'n_estimators': 150, 'learning_rate': 0.06150196922658207, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.25, 'min_child_weight': 9, 'lambda': 0.003215321903879615, 'alpha': 0.5392156185147712}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:12,044] Trial 44 finished with value: 0.9201038113722501 and parameters: {'n_estimators': 200, 'learning_rate': 0.09604942122073012, 'max_depth': 4, 'subsample': 0.85, 'colsample_bytree': 0.75, 'gamma': 0.0, 'min_child_weight': 10, 'lambda': 0.006304029967265406, 'alpha': 0.2113694873380234}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:12,659] Trial 45 finished with value: 0.9187481491852815 and parameters: {'n_estimators': 150, 'learning_rate': 0.07886262835914945, 'max_depth': 7, 'subsample': 0.9, 'colsample_bytree': 0.65, 'gamma': 0.30000000000000004, 'min_child_weight': 8, 'lambda': 0.053105363818185966, 'alpha': 0.3316553090596919}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:13,045] Trial 46 finished with value: 0.9210341862396568 and parameters: {'n_estimators': 100, 'learning_rate': 0.1623018817728132, 'max_depth': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.4, 'min_child_weight': 8, 'lambda': 0.0188705257566301, 'alpha': 0.18304310124107168}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:13,658] Trial 47 finished with value: 0.9190889136118985 and parameters: {'n_estimators': 250, 'learning_rate': 0.10946666019076615, 'max_depth': 4, 'subsample': 0.9, 'colsample_bytree': 0.75, 'gamma': 0.30000000000000004, 'min_child_weight': 9, 'lambda': 0.00279350285608146, 'alpha': 0.32731722265066493}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:14,261] Trial 48 finished with value: 0.9208743154554266 and parameters: {'n_estimators': 300, 'learning_rate': 0.07963884568712923, 'max_depth': 3, 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0.25, 'min_child_weight': 9, 'lambda': 0.038968092957346205, 'alpha': 0.6166621112028301}. Best is trial 42 with value: 0.9215268310128101.
# [I 2025-05-05 11:20:15,215] Trial 49 finished with value: 0.9211092353216523 and parameters: {'n_estimators': 500, 'learning_rate': 0.04837663468172752, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.7, 'gamma': 0.35000000000000003, 'min_child_weight': 10, 'lambda': 0.013579991754161944, 'alpha': 0.47168899150800897}. Best is trial 42 with value: 0.9215268310128101.
# Optuna Optimization Complete
#
#
# Number of finished trials: 50
# Best trial number: 42
# Best ROC AUC (CV on Train Set): 0.9215
#
# Best Parameters found:
#
# {'n_estimators': 200, 'learning_rate': 0.060117183434070784, 'max_depth': 3, 'subsample': 0.85, 'colsample_bytree': 0.75, 'gamma': 0.30000000000000004, 'min_child_weight': 9, 'lambda': 0.0029278622871275056, 'alpha': 0.20033053974980772}

# %%
# Train Final Model with Best Parameters
print("\nTraining Final Model with Best Parameters on Full Training Set")

# Add back fixed parameters that weren't tuned
final_params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss', 
    'booster': 'gbtree',
    'random_state': 42,
}
final_params.update(best_params) # Combine fixed and tuned parameters

best_xgb_model_optuna = xgb.XGBClassifier(**final_params)
best_xgb_model_optuna.fit(X_train, y_train)

print("Final model trained.")
# Out:
# Training Final Model with Best Parameters on Full Training Set
# Final model trained.

# %% [markdown]
# ### Make Predictions

# %%
y_pred_train = best_xgb_model_optuna.predict(X_train)
y_pred_test = best_xgb_model_optuna.predict(X_test)
y_pred_proba_train = best_xgb_model_optuna.predict_proba(X_train)[:, 1] 
y_pred_proba_test = best_xgb_model_optuna.predict_proba(X_test)[:, 1] 

print("Predictions made on training and testing sets.")
# Out:
# Predictions made on training and testing sets.

# %%
threshold = 0.4

# Apply Threshold 

y_pred_train = (y_pred_proba_train >= threshold).astype(int)
y_pred_test = (y_pred_proba_test >= threshold).astype(int)

# %% [markdown]
# ### Evaluate Model Performance

# %%
# Training Set Performance 

print("\nTraining Set Performance\n")
print(f"Accuracy: {accuracy_score(y_train, y_pred_train):.4f}")
print("Confusion Matrix:\n")
print(confusion_matrix(y_train, y_pred_train))
print("\nClassification Report:")
print(classification_report(y_train, y_pred_train))
# Out:
# Training Set Performance
#
# Accuracy: 0.8519
# Confusion Matrix:
#
# [[ 6896  2333]
#  [  967 12084]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81      9229
#            1       0.84      0.93      0.88     13051
#
#     accuracy                           0.85     22280
#    macro avg       0.86      0.84      0.84     22280
# weighted avg       0.85      0.85      0.85     22280

# %%
#Testing Set Performance

print("\nTesting Set Performance\n")
accuracy_test = accuracy_score(y_test, y_pred_test)
print(f"Accuracy: {accuracy_test:.4f}")

# Plot Confusion Matrix
cm_test = confusion_matrix(y_test, y_pred_test) 

tn, fp, fn, tp = cm_test.ravel()

display_matrix_final = np.array([[tp, fp],
                                 [fn, tn]])

x_labels_final = ["Actual Positive (1)", "Actual Negative (0)"]
y_labels_final = ["Predicted Positive (1)", "Predicted Negative (0)"]

plt.figure(figsize=(6, 4))
sns.heatmap(display_matrix_final,
            annot=True,                
            fmt='d',                   
            cmap='Blues',              
            cbar=False,                
            xticklabels=x_labels_final, 
            yticklabels=y_labels_final) 

plt.xlabel("Actual Depression") 
plt.ylabel("Predicted Depression") 
plt.title("Confusion Matrix (Test Set)") 
plt.yticks(rotation=0)
plt.show()

print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Testing Set Performance
#
# Accuracy: 0.8438
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.74      0.80      2308
#            1       0.83      0.92      0.87      3263
#
#     accuracy                           0.84      5571
#    macro avg       0.85      0.83      0.84      5571
# weighted avg       0.85      0.84      0.84      5571

# %%
# ROC AUC Score 
roc_auc = roc_auc_score(y_test, y_pred_proba_test)
print(f"\nROC AUC Score (Test Set): {roc_auc:.4f}")
# Out:
# ROC AUC Score (Test Set): 0.9221

# %%
# Plot ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba_test)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve (Test Set)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Plot Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_pred_proba_test)
pr_auc = auc(recall, precision)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2, label=f'PR curve (area = {pr_auc:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Test Set)')
plt.legend(loc="lower left")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Feature Importance

# %%
print("\n-Feature Importance")

if hasattr(best_xgb_model_optuna, 'feature_importances_'):
    feature_importances = pd.DataFrame({
        'feature': X.columns,
        'importance': best_xgb_model_optuna.feature_importances_
    }).sort_values('importance', ascending=False)

    print("Top 20 Feature Importances:")
    print(feature_importances.head(20))

    # Plot top N feature importances
    plt.figure(figsize=(10, 8))
    sns.barplot(x='importance', y='feature', data=feature_importances.head(20), palette='viridis')
    plt.title('Top 20 Feature Importances (XGBoost)')
    plt.tight_layout()
    plt.show()
else:
    print("Could not retrieve feature importances from the model.")
# Out:
# -Feature Importance
# Top 20 Feature Importances:
#                              feature  importance
# 4                  Suicidal_Thoughts    0.366391
# 9                       Total_Stress    0.109729
# 1                  Academic Pressure    0.080718
# 6                   Financial Stress    0.078882
# 42          Dietary Habits_Unhealthy    0.028068
# 0                                Age    0.026914
# 5                   Work/Study Hours    0.023891
# 3                 Study Satisfaction    0.019251
# 71                   Age_Group_31-39    0.017310
# 40           Dietary Habits_Moderate    0.014374
# 8                      Sleep_Ordinal    0.011730
# 53                   Degree_Class 12    0.009002
# 7   Family History of Mental Illness    0.007829
# 60                         Degree_MA    0.006926
# 56                      Degree_M.Com    0.006203
# 73                   Region_Northern    0.006193
# 20                       City_Jaipur    0.005557
# 31                         City_Pune    0.005510
# 63                        Degree_MCA    0.005299
# 44                       Degree_B.Ed    0.005283

# %% [markdown]
# ### Save the Model

# %%
model_filename_joblib = 'Models/xgboost_tuned_model.joblib'
model_filename_xgb = 'Models/xgboost_tuned_model.xgb' 
model_filename_json = 'Models/xgboost_tuned_model.json' 
columns_filename = 'Models/feature_columns_final.joblib'

# Saving the Model using joblib 

joblib.dump(best_xgb_model_optuna, model_filename_joblib)
print(f"\nModel successfully saved using joblib to: '{model_filename_joblib}'")


# Saving the Model using XGBoost's save_model

best_xgb_model_optuna.save_model(model_filename_json)
print(f"Model successfully saved using native XGBoost (JSON) to: '{model_filename_json}'")

best_xgb_model_optuna.save_model(model_filename_xgb) # binary format
print(f"Model successfully saved using native XGBoost (Binary) to: '{model_filename_xgb}'")
      
# Saving the Feature Columns List
feature_columns = list(X_train.columns)
joblib.dump(feature_columns, columns_filename)
print(f"Feature column list successfully saved to: '{columns_filename}'")
print(f"(Saved {len(feature_columns)} column names)")
# Out:
# Model successfully saved using joblib to: 'Models/xgboost_tuned_model.joblib'
# Model successfully saved using native XGBoost (JSON) to: 'Models/xgboost_tuned_model.json'
# Model successfully saved using native XGBoost (Binary) to: 'Models/xgboost_tuned_model.xgb'
# Feature column list successfully saved to: 'Models/feature_columns_final.joblib'
# (Saved 90 column names)
